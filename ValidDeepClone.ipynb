# %%
import sys

# %%
sys.path.append(r'G:\PycharmProject\PycomCAD\PycomCAD')

# %%
from pycomcad import *

acad=Autocad()

acad.CurrentFilename

slt=acad.GetSelectionSets('slt1')
slt.SelectOnScreen()
result1=acad.DeepClone(slt,'Drawing2.dwg')

# %%
from pycomcad import *

# %%
acad=Autocad()

# %%
acad.CurrentFilename
# Out:
# 'Drawing1.dwg'

# %%
slt=acad.GetSelectionSets('1')

# %%
slt.SelectOnScreen()

# %%
acad.ActivateFile(index=0)

# %%
acad.DeepClone(slt,1)
# Out:
# ((<win32com.gen_py.AutoCAD 2016 Type Library.IAcadLWPolyline instance at 0x2616008355680>,
#   <win32com.gen_py.AutoCAD 2016 Type Library.IAcadBlockReference instance at 0x2616008355736>,
#   <win32com.gen_py.AutoCAD 2016 Type Library.IAcadBlockReference instance at 0x2616008355792>,
#   <win32com.gen_py.AutoCAD 2016 Type Library.IAcadLWPolyline instance at 0x2616008364104>,
#   <win32com.gen_py.AutoCAD 2016 Type Library.IAcadLine instance at 0x2616008364160>,
#   <win32com.gen_py.AutoCAD 2016 Type Library.IAcadText instance at 0x2616008364216>,
#   <win32com.gen_py.AutoCAD 2016 Type Library.IAcadText instance at 0x2616008364272>,
#   <win32com.gen_py.AutoCAD 2016 Type Library.IAcadLine instance at 0x2616008364328>,
#   <win32com.gen_py.AutoCAD 2016 Type Library.IAcadText instance at 0x2616008364384>,
#   <win32com.gen_py.AutoCAD 2016 Type Library.IAcadText instance at 0x2616008364440>,
#   <win32com.gen_py.AutoCAD 2016 Type Library.IAcadLine instance at 0x2616008364496>,
# ...
